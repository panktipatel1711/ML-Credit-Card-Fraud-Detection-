# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# The "../" goes up one level to find the 'data' folder
# Change the filename if yours is different (e.g., creditcard_sample.csv)
df = pd.read_csv('../data/row/creditcard.csv')

# Check first 5 rows
print(df.head())

# Check for fraud distribution
sns.countplot(x='Class', data=df)
plt.title('Transaction Class Distribution (0: Safe, 1: Fraud)')
plt.show()
